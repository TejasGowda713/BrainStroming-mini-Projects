# %%
import texttable as tt
import requests
from  bs4 import BeautifulSoup

# %%
url = "https://www.worldometers.info/coronavirus/countries-where-coronavirus-has-spread/"

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")

# %%
data = []

# %%
data_iterator = iter(soup.find_all('td'))

# %%
while True:
    try:
        country = next(data_iterator).text
        confirmed = next(data_iterator).text
        deaths = next(data_iterator).text
        continent = next(data_iterator).text
        data.append((
            country,
            (confirmed.replace(', ', '')),
            (deaths.replace(', ', '')),
            continent
        ))
    except StopIteration:
        break

# %%
#data.sort(key = lambda row: row[1],reverse=True)

# %%
table = tt.Texttable()
table.add_rows([(None, None, None, None)] + data)
table.set_cols_align(('c', 'c', 'c', 'c'))
table.header((' Country', ' Number of cases', ' Deaths', ' Continent'))

# %%
print(table.draw())
# Out:
# +---------------------------+------------------+---------+-------------------+
# |          Country          |  Number of cases |  Deaths |     Continent     |
# +===========================+==================+=========+===================+
# |       United States       |    1,848,555     | 106,542 |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Brazil           |     519,704      | 29,534  |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |          Russia           |     414,878      |  4,855  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |           Spain           |     286,718      | 27,127  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |      United Kingdom       |     276,332      | 39,045  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |           Italy           |     233,197      | 33,475  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |           India           |     198,343      |  5,608  |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          France           |     189,220      | 28,833  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Germany          |     183,663      |  8,613  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Turkey           |     164,769      |  4,563  |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |           Peru            |     164,476      |  4,506  |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |           Iran            |     154,445      |  7,878  |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |           Chile           |     105,159      |  1,113  |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |          Canada           |      91,647      |  7,325  |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Mexico           |      90,664      |  9,930  |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |       Saudi Arabia        |      87,142      |   525   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |           China           |      83,017      |  4,634  |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |         Pakistan          |      72,460      |  1,543  |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Belgium          |      58,517      |  9,486  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |           Qatar           |      58,433      |   40    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |        Bangladesh         |      49,534      |   672   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |        Netherlands        |      46,545      |  5,962  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Belarus          |      43,403      |   240   |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Ecuador          |      39,098      |  3,358  |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |          Sweden           |      37,814      |  4,403  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |         Singapore         |      35,292      |   24    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |   United Arab Emirates    |      35,192      |   266   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |       South Africa        |      34,357      |   705   |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |         Portugal          |      32,700      |  1,424  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |        Switzerland        |      30,871      |  1,920  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |         Colombia          |      29,383      |   939   |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |          Kuwait           |      27,762      |   220   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |         Indonesia         |      26,940      |  1,641  |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |           Egypt           |      26,384      |  1,005  |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Ireland          |      25,062      |  1,652  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Poland           |      24,165      |  1,074  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Ukraine          |      24,012      |   718   |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Romania          |      19,398      |  1,276  |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |        Philippines        |      18,638      |   960   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |    Dominican Republic     |      17,572      |   502   |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Israel           |      17,169      |   285   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# | Japan (+Diamond Princess) |      17,563      |   904   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |         Argentina         |      16,851      |   541   |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |          Austria          |      16,733      |   668   |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |        Afghanistan        |      15,750      |   265   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Panama           |      13,463      |   336   |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |           Oman            |      12,223      |   50    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Bahrain          |      11,871      |   19    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Denmark          |      11,699      |   576   |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |        South Korea        |      11,503      |   271   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Serbia           |      11,430      |   244   |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |        Kazakhstan         |      11,308      |   41    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Nigeria          |      10,162      |   287   |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Bolivia          |      9,982       |   313   |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |          Algeria          |      9,513       |   661   |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Armenia          |      9,492       |   139   |       Asia        |
# +---------------------------+------------------+---------+-------------------+
|       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |           Togo            |       443        |   13    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Taiwan           |       443        |    7    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Rwanda           |       370        |    1    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |           Yemen           |       354        |   84    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |        Isle of Man        |       336        |   24    |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Malawi           |       336        |    4    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |         Mauritius         |       335        |   10    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Vietnam          |       328        |    0    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |        Montenegro         |       324        |    9    |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |          Liberia          |       296        |   27    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |         Eswatini          |       293        |    3    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |        Mozambique         |       254        |    2    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |           Benin           |       232        |    3    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Myanmar          |       228        |    6    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |        Martinique         |       200        |   14    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |      Faeroe Islands       |       187        |    0    |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |         Mongolia          |       185        |    0    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |         Zimbabwe          |       178        |    4    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |         Gibraltar         |       170        |    0    |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |        Guadeloupe         |       162        |   14    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |           Libya           |       156        |    5    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Guyana           |       153        |   12    |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |          Brunei           |       141        |    2    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |      Cayman Islands       |       141        |    1    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Bermuda          |       140        |    9    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |         Cambodia          |       125        |    0    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |           Syria           |       123        |    5    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |    Trinidad and Tobago    |       117        |    8    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Comoros          |       106        |    2    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Bahamas          |       102        |   11    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |           Aruba           |       101        |    3    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Monaco           |        99        |    4    |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |         Barbados          |        92        |    7    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Angola           |        86        |    4    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |       Liechtenstein       |        82        |    1    |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |       Sint Maarten        |        77        |   15    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Burundi          |        63        |    1    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |     French Polynesia      |        60        |    0    | Australia/Oceania |
# +---------------------------+------------------+---------+-------------------+
# |           Macao           |        45        |    0    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Bhutan           |        43        |    0    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |       Saint Martin        |        41        |    3    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Eritrea          |        39        |    0    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |         Botswana          |        38        |    1    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |         Suriname          |        28        |    1    |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |    Antigua and Barbuda    |        26        |    3    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# | St. Vincent & Grenadines  |        26        |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Gambia           |        25        |    1    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |          Namibia          |        25        |    0    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |        Timor-Leste        |        24        |    0    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Grenada          |        23        |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |       New Caledonia       |        20        |    0    | Australia/Oceania |
# +---------------------------+------------------+---------+-------------------+
# |          Curaçao          |        19        |    1    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |           Laos            |        19        |    0    |       Asia        |
# +---------------------------+------------------+---------+-------------------+
# |          Belize           |        18        |    2    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |        Saint Lucia        |        18        |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |           Fiji            |        18        |    0    | Australia/Oceania |
# +---------------------------+------------------+---------+-------------------+
# |         Dominica          |        16        |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |    Saint Kitts & Nevis    |        15        |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |         Greenland         |        13        |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |     Falkland Islands      |        13        |    0    |   South America   |
# +---------------------------+------------------+---------+-------------------+
# |     Turks and Caicos      |        12        |    1    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |         Holy See          |        12        |    0    |      Europe       |
# +---------------------------+------------------+---------+-------------------+
# |        Montserrat         |        11        |    1    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |        Seychelles         |        11        |    0    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |        MS Zaandam         |        9         |    2    |                   |
# +---------------------------+------------------+---------+-------------------+
# |      Western Sahara       |        9         |    1    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |  British Virgin Islands   |        8         |    1    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |     Papua New Guinea      |        8         |    0    | Australia/Oceania |
# +---------------------------+------------------+---------+-------------------+
# |   Caribbean Netherlands   |        7         |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |     Saint Barthelemy      |        6         |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |         Anguilla          |        3         |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
# |          Lesotho          |        2         |    0    |      Africa       |
# +---------------------------+------------------+---------+-------------------+
# |  Saint Pierre & Miquelon  |        1         |    0    |   North America   |
# +---------------------------+------------------+---------+-------------------+
